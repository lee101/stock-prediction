# %%
# %run visualize_preds.py
# Out:
# /home/lee/code/stock/results/predictions-2022-01-07_01-33-36.csv
# /home/lee/code/stock/results/predictions-2022-01-07_01-33-46.csv
# /home/lee/code/stock/results/predictions-2022-01-07_01-34-04.csv
# /home/lee/code/stock/results/predictions-2022-01-07_01-34-12.csv
# /home/lee/code/stock/results/predictions-2022-01-07_01-34-30.csv
# /home/lee/code/stock/results/predictions-2022-01-07_01-34-37.csv
# /home/lee/code/stock/results/predictions-2022-01-07_01-34-56.csv
# /home/lee/code/stock/results/predictions-2022-01-07_01-35-03.csv
# /home/lee/code/stock/results/predictions-2022-01-07_01-35-23.csv
# /home/lee/code/stock/results/predictions-2022-01-07_01-35-32.csv
# /home/lee/code/stock/results/predictions-2022-01-07_01-35-50.csv
# /home/lee/code/stock/results/predictions-2022-01-07_01-35-58.csv
# /home/lee/code/stock/results/predictions-2022-01-07_01-36-16.csv
# /home/lee/code/stock/results/predictions-2022-01-07_01-36-24.csv
# ...

# %%
import matplotlib.pyplot as plt
plt.show()
